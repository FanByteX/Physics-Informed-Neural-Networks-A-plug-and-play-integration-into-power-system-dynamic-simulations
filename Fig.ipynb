# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.ticker import ScalarFormatter # 导入格式化工具
import os

# 1. 全局字体与样式设置 (强制统一为 Times 风格)
plt.rcParams.update({
    "text.usetex": False,            # 不需要安装完整的 LaTeX 也能运行
    "font.family": "serif",          # 使用衬线体
    "font.serif": ["Times New Roman", "DejaVu Serif"], # DejaVu Serif 作为备选
    "mathtext.fontset": "stix",      # 核心设置：让数学公式也使用类 Times 字体
    "axes.labelsize": 20,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
    "legend.fontsize": 18,
    "axes.unicode_minus": False      # 正常显示负号
})
